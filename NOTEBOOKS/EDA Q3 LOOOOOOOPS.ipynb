# %% [markdown]
# <h1 style="color: #F70206; text-shadow: 2px 2px 4px #000000; border: 1px solid #000000; font-size: 60px; text-align: center; background-color: #A1A1A3;"> 🏎️ FORMULA 1: LAP TIMES 🏎️ </h1>

# %% [markdown]
# <h1 style="color: #F70206; text-shadow: 2px 2px 4px #000000; border: 1px solid #000000; font-size: 36px;">00 | First Steps </h1>

# %%
import pandas as pd                                      # 😀 Importa la biblioteca pandas y la renombra como pd para su uso en el código.
import matplotlib.pyplot as plt                          # 📊 Importa la biblioteca matplotlib.pyplot y la renombra como plt para su uso en el código.
import seaborn as sns                                    # 📈 Importa la biblioteca seaborn para gráficos estadísticos.
import numpy as np                                       # 🔢 Importa la biblioteca numpy y la renombra como np para su uso en el código.
from scipy.stats import chi2_contingency                 # 📊 Importa la función chi2_contingency de la biblioteca scipy.stats para realizar pruebas de independencia.
from scipy.stats.contingency import association          # 📊 Importa la función association de la biblioteca scipy.stats.contingency para calcular medidas de asociación en tablas de contingencia.
import statsmodels.api as sm                             # 📈 Importa la biblioteca statsmodels.api para análisis estadístico y modelado.
import scipy.stats as st                                 # 🔬 Importa la biblioteca scipy.stats para distribuciones y pruebas estadísticas.
from sklearn.model_selection import train_test_split     # 🛠️ Importa la función train_test_split de la biblioteca sklearn.model_selection para dividir datos en conjuntos de entrenamiento y prueba.
from sklearn.linear_model import LinearRegression        # 📈 Importa el modelo de regresión lineal de la biblioteca sklearn.linear_model.
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error  # 📊 Importa métricas de evaluación de modelos de la biblioteca sklearn.metrics.
from sklearn.linear_model import Ridge                   # 📈 Importa el modelo de regresión Ridge de la biblioteca sklearn.linear_model.
from sklearn.linear_model import Lasso                   # 📈 Importa el modelo de regresión Lasso de la biblioteca sklearn.linear_model.
from sklearn.tree import DecisionTreeRegressor           # 🌳 Importa el modelo de regresión de árbol de decisión de la biblioteca sklearn.tree.
from sklearn.neighbors import KNeighborsRegressor        # 🏠 Importa el modelo de regresión de vecinos más cercanos de la biblioteca sklearn.neighbors.
from sklearn.preprocessing import MinMaxScaler           # 📏 Importa la clase MinMaxScaler de la biblioteca sklearn.preprocessing para escalar características al rango [0, 1].
from sklearn.preprocessing import StandardScaler         # 📏 Importa la clase StandardScaler de la biblioteca sklearn.preprocessing para estandarizar características eliminando la media y escalando a la varianza unitaria.
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.utils import resample
import xgboost as xgb                                    # 🚀 Importa la biblioteca xgboost para el modelado de gradient boosting.
import warnings                                          # ⚠️ Importa la biblioteca warnings para manejar advertencias.
from datetime import datetime                            # 📅 Importa la clase datetime de la biblioteca datetime para trabajar con fechas y horas.
from sklearn import preprocessing                        # 🛠️ Importa el módulo preprocessing de la biblioteca sklearn para realizar preprocesamiento de datos.

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: rgba(247, 2, 6, 0.2); color: black;">
#     <strong>Tip #1</strong> RELLENAR!
# </div>

# %% [markdown]
# <h4 style="color: #F70206;">Other settings</h4>

# %%
warnings.filterwarnings("ignore")
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# data2 = pd.read_csv("dfq3.csv")
# df2 = data2.copy()
# df2 = df2[df2["circuitref"] == "bahrain"]
# df2 = df2.sort_values(by=['year', 'driverid'], ascending=[True, True])

# %% [markdown]
# <h4 style="color: #F70206;">Data Extraction</h4>

# %% [markdown]
# data01 = pd.read_csv("df1_baku_q1_predicted_trabajar_posiciones_finales.csv")
# data01

# %% [markdown]
# data02 = pd.read_csv("df1_baku_q1_predicted_q2_predicted.csv")
# data02

# %% [markdown]
# data03 = pd.read_csv("dfq3.csv")

# %%
file_names2 = ['df1_bahrain_q1_predicted_q2_predicted.csv', 
              'df1_albert_park_q1_predicted_q2_predicted.csv',
              'df1_suzuka_q1_predicted_q2_predicted.csv', 
              'df1_miami_q1_predicted_q2_predicted.csv', 
              'df1_imola_q1_predicted_q2_predicted.csv', 
              'df1_monaco_q1_predicted_q2_predicted.csv', 
              'df1_villeneuve_q1_predicted_q2_predicted.csv', 
              'df1_catalunya_q1_predicted_q2_predicted.csv',
              'df1_red_bull_ring_q1_predicted_q2_predicted.csv',
              'df1_silverstone_q1_predicted_q2_predicted.csv',
              'df1_hungaroring_q1_predicted_q2_predicted.csv', 
              'df1_spa_q1_predicted_q2_predicted.csv', 
              'df1_zandvoort_q1_predicted_q2_predicted.csv', 
              'df1_monza_q1_predicted_q2_predicted.csv', 
              'df1_baku_q1_predicted_q2_predicted.csv', 
              'df1_marina_bay_q1_predicted_q2_predicted.csv', 
              'df1_americas_q1_predicted_q2_predicted.csv',
              'df1_rodriguez_q1_predicted_q2_predicted.csv', 
              'df1_interlagos_q1_predicted_q2_predicted.csv', 
              'df1_losail_q1_predicted_q2_predicted.csv', 
              'df1_yas_marina_q1_predicted_q2_predicted.csv']

dfs2 = {}

for file_name2 in file_names2:
    track_name = file_name2.replace(".csv", "")
    dfs2[track_name] = pd.read_csv(file_name2)

# Crear variables para cada DataFrame
for track_name, df in dfs2.items():
    # Generar el nombre de la variable dinámicamente
    variable_name = f"df_{track_name.split('_q1')[0]}"
    # Asignar el DataFrame al nombre de la variable
    globals()[variable_name] = df

dfs_list = []

for file_name2 in file_names2:
    track_name = file_name2.replace(".csv", "")
    dfs_list.append(f"dfs2['{track_name}']")
    
print(dfs_list)
# Out:
# ["dfs2['df1_bahrain_q1_predicted_q2_predicted']", "dfs2['df1_albert_park_q1_predicted_q2_predicted']", "dfs2['df1_suzuka_q1_predicted_q2_predicted']", "dfs2['df1_miami_q1_predicted_q2_predicted']", "dfs2['df1_imola_q1_predicted_q2_predicted']", "dfs2['df1_monaco_q1_predicted_q2_predicted']", "dfs2['df1_villeneuve_q1_predicted_q2_predicted']", "dfs2['df1_catalunya_q1_predicted_q2_predicted']", "dfs2['df1_red_bull_ring_q1_predicted_q2_predicted']", "dfs2['df1_silverstone_q1_predicted_q2_predicted']", "dfs2['df1_hungaroring_q1_predicted_q2_predicted']", "dfs2['df1_spa_q1_predicted_q2_predicted']", "dfs2['df1_zandvoort_q1_predicted_q2_predicted']", "dfs2['df1_monza_q1_predicted_q2_predicted']", "dfs2['df1_baku_q1_predicted_q2_predicted']", "dfs2['df1_marina_bay_q1_predicted_q2_predicted']", "dfs2['df1_americas_q1_predicted_q2_predicted']", "dfs2['df1_rodriguez_q1_predicted_q2_predicted']", "dfs2['df1_interlagos_q1_predicted_q2_predicted']", "dfs2['df1_losail_q1_predicted_q2_predicted']",
# ...

# %%
dfs2['df1_bahrain_q1_predicted_q2_predicted']
dfs2['df1_albert_park_q1_predicted_q2_predicted'] 
dfs2['df1_suzuka_q1_predicted_q2_predicted']
dfs2['df1_miami_q1_predicted_q2_predicted']
dfs2['df1_imola_q1_predicted_q2_predicted'] 
dfs2['df1_monaco_q1_predicted_q2_predicted']
dfs2['df1_villeneuve_q1_predicted_q2_predicted'] 
dfs2['df1_catalunya_q1_predicted_q2_predicted']
dfs2['df1_red_bull_ring_q1_predicted_q2_predicted']
dfs2['df1_silverstone_q1_predicted_q2_predicted']
dfs2['df1_hungaroring_q1_predicted_q2_predicted'] 
dfs2['df1_spa_q1_predicted_q2_predicted']
dfs2['df1_zandvoort_q1_predicted_q2_predicted'] 
dfs2['df1_monza_q1_predicted_q2_predicted'] 
dfs2['df1_baku_q1_predicted_q2_predicted']
dfs2['df1_marina_bay_q1_predicted_q2_predicted'] 
dfs2['df1_americas_q1_predicted_q2_predicted']
dfs2['df1_rodriguez_q1_predicted_q2_predicted'] 
dfs2['df1_interlagos_q1_predicted_q2_predicted'] 
dfs2['df1_losail_q1_predicted_q2_predicted'] 
dfs2['df1_yas_marina_q1_predicted_q2_predicted']
# Out:
#     qualifyid  driverid  constructorid    year  round  circuitid  position_q1  \
# 0     10315.0       1.0          131.0  2024.0   24.0       24.0          5.0
# 1     10317.0       4.0          117.0  2024.0   24.0       24.0          3.0
# 2     10325.0     840.0          117.0  2024.0   24.0       24.0          9.0
# 3     10332.0     807.0          213.0  2024.0   24.0       24.0         12.0
# 4     10331.0     817.0          213.0  2024.0   24.0       24.0          8.0
# 5     10319.0     815.0            9.0  2024.0   24.0       24.0          6.0
# 6     10314.0     830.0            9.0  2024.0   24.0       24.0          7.0
# 7     10322.0     822.0           51.0  2024.0   24.0       24.0          4.0
# 8     10329.0     855.0           51.0  2024.0   24.0       24.0         15.0
# 9     10316.0     832.0            6.0  2024.0   24.0       24.0         13.0
# 10    10313.0     844.0            6.0  2024.0   24.0       24.0         14.0
# ...

# %%
file_names = ['df1_bahrain_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_albert_park_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_suzuka_q1_predicted_trabajar_posiciones_finales.csv',
              'df1_miami_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_imola_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_monaco_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_villeneuve_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_catalunya_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_red_bull_ring_q1_predicted_trabajar_posiciones_finales.csv',
              'df1_silverstone_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_hungaroring_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_spa_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_zandvoort_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_monza_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_baku_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_marina_bay_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_americas_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_rodriguez_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_interlagos_q1_predicted_trabajar_posiciones_finales.csv',
              'df1_losail_q1_predicted_trabajar_posiciones_finales.csv', 
              'df1_yas_marina_q1_predicted_trabajar_posiciones_finales.csv']

dfs = {}
for file_name in file_names:
    track_name = file_name.replace(".csv", "")
    dfs[track_name] = pd.read_csv(file_name)

for track_name, df in dfs.items():
    df.loc[df["q2disqualified"] == 1, "q2"] = 0
    df.loc[df['position_q1'] > 15, 'position_q2'] = df['position_q1']

# %%
dfs["df1_losail_q1_predicted_trabajar_posiciones_finales"]
# Out:
#     qualifyid  raceid  driverid  constructorid  position_final    year  round  \
# 0      9116.0    1051       1.0          131.0             1.0  2021.0   20.0
# 1      9118.0    1051     822.0          131.0             3.0  2021.0   20.0
# 2      9120.0    1051       4.0          214.0             6.0  2021.0   20.0
# 3      9124.0    1051     839.0          214.0            11.0  2021.0   20.0
# 4      9131.0    1051       8.0           51.0            16.0  2021.0   20.0
# 5      9133.0    1051     841.0           51.0            18.0  2021.0   20.0
# 6      9125.0    1051      20.0          117.0             9.0  2021.0   20.0
# 7      9127.0    1051     840.0          117.0            10.0  2021.0   20.0
# 8      9126.0    1051     815.0            9.0             5.0  2021.0   20.0
# 9      9117.0    1051     830.0            9.0             2.0  2021.0   20.0
# 10     9129.0    1051     817.0            1.0            12.0  2021.0   20.0
# ...

# %%
dfs2['df1_bahrain_q1_predicted_q2_predicted']
# Out:
#     qualifyid  driverid  constructorid    year  round  circuitid  position_q1  \
# 0      9875.0       1.0          131.0  2024.0    1.0        3.0          4.0
# 1      9877.0       4.0          117.0  2024.0    1.0        3.0          9.0
# 2      9885.0     840.0          117.0  2024.0    1.0        3.0         14.0
# 3      9892.0     807.0          213.0  2024.0    1.0        3.0         13.0
# 4      9891.0     817.0          213.0  2024.0    1.0        3.0          1.0
# 5      9881.0     852.0          213.0  2024.0    1.0        3.0         10.0
# 6      9879.0     815.0            9.0  2024.0    1.0        3.0          3.0
# 7      9882.0     822.0           51.0  2024.0    1.0        3.0          2.0
# 8      9889.0     855.0           51.0  2024.0    1.0        3.0          8.0
# 9      9887.0     825.0          210.0  2024.0    1.0        3.0          5.0
# 10     9876.0     832.0            6.0  2024.0    1.0        3.0         12.0
# ...

# %% [markdown]
# nans =  dfs2['df1_bahrain_q1_predicted_q2_predicted']["predictions_real_xgb"]

# %% [markdown]
# dfs["df1_bahrain_q1_predicted_trabajar_posiciones_finales"]["q2"] = dfs["df1_bahrain_q1_predicted_trabajar_posiciones_finales"]["q2"].fillna(nans)

# %% [markdown]
# nans.shape

# %%
# Lista de tuplas de los nombres de los DataFrames correspondientes en dfs y dfs2
dataframes_pairs = [
    ("df1_bahrain_q1_predicted_trabajar_posiciones_finales", "df1_bahrain_q1_predicted_q2_predicted"),
    ("df1_albert_park_q1_predicted_trabajar_posiciones_finales", "df1_albert_park_q1_predicted_q2_predicted"),
    ("df1_suzuka_q1_predicted_trabajar_posiciones_finales", "df1_suzuka_q1_predicted_q2_predicted"),
    ("df1_miami_q1_predicted_trabajar_posiciones_finales", "df1_miami_q1_predicted_q2_predicted"),
    ("df1_imola_q1_predicted_trabajar_posiciones_finales", "df1_imola_q1_predicted_q2_predicted"),
    ("df1_monaco_q1_predicted_trabajar_posiciones_finales", "df1_monaco_q1_predicted_q2_predicted"),
    ("df1_villeneuve_q1_predicted_trabajar_posiciones_finales", "df1_villeneuve_q1_predicted_q2_predicted"),
    ("df1_catalunya_q1_predicted_trabajar_posiciones_finales", "df1_catalunya_q1_predicted_q2_predicted"),
    ("df1_red_bull_ring_q1_predicted_trabajar_posiciones_finales", "df1_red_bull_ring_q1_predicted_q2_predicted"),
    ("df1_silverstone_q1_predicted_trabajar_posiciones_finales", "df1_silverstone_q1_predicted_q2_predicted"),
    ("df1_hungaroring_q1_predicted_trabajar_posiciones_finales", "df1_hungaroring_q1_predicted_q2_predicted"),
    ("df1_spa_q1_predicted_trabajar_posiciones_finales", "df1_spa_q1_predicted_q2_predicted"),
    ("df1_zandvoort_q1_predicted_trabajar_posiciones_finales", "df1_zandvoort_q1_predicted_q2_predicted"),
    ("df1_monza_q1_predicted_trabajar_posiciones_finales", "df1_monza_q1_predicted_q2_predicted"),
    ("df1_baku_q1_predicted_trabajar_posiciones_finales", "df1_baku_q1_predicted_q2_predicted"),
    ("df1_marina_bay_q1_predicted_trabajar_posiciones_finales", "df1_marina_bay_q1_predicted_q2_predicted"),
    ("df1_americas_q1_predicted_trabajar_posiciones_finales", "df1_americas_q1_predicted_q2_predicted"),
    ("df1_rodriguez_q1_predicted_trabajar_posiciones_finales", "df1_rodriguez_q1_predicted_q2_predicted"),
    ("df1_interlagos_q1_predicted_trabajar_posiciones_finales", "df1_interlagos_q1_predicted_q2_predicted"),
    ("df1_losail_q1_predicted_trabajar_posiciones_finales", "df1_losail_q1_predicted_q2_predicted"),
    ("df1_yas_marina_q1_predicted_trabajar_posiciones_finales", "df1_yas_marina_q1_predicted_q2_predicted")
]

# Iterar sobre los pares de DataFrames
for df1_name, df2_name in dataframes_pairs:
    # Obtener los DataFrames correspondientes
    df1 = dfs[df1_name]
    df2 = dfs2[df2_name]
    
    # Agrupar el segundo DataFrame por 'driverid' y 'year' y seleccionar las columnas relevantes
    grouped = df2.groupby(['driverid', 'year'])[['q2', "position_q2"]]
    
    # Iterar sobre los grupos
    for (driverid, year), group_df in grouped:
        # Filtrar el primer DataFrame para las filas que coincidan con el 'driverid' y 'year' actuales
        mask = (df1['driverid'] == driverid) & (df1['year'] == year)
        # Asignar los valores correspondientes del segundo DataFrame al primer DataFrame
        df1.loc[mask, 'q2'] = group_df['q2'].values
        df1.loc[mask, 'position_q2'] = group_df['position_q2'].values
        # Actualizar el DataFrame en dfs
        dfs[df1_name] = df1

# %% [markdown]
# file_names_q2_prediction = [
#     "df1_bahrain_q1_predicted_q2_predicted.csv",
#     "df1_albert_park_q1_predicted_q2_predicted.csv",
#     "df1_suzuka_q1_predicted_q2_predicted.csv",
#     "df1_miami_q1_predicted_q2_predicted.csv",
#     "df1_imola_q1_predicted_q2_predicted.csv",
#     "df1_monaco_q1_predicted_q2_predicted.csv",
#     "df1_villeneuve_q1_predicted_q2_predicted.csv",
#     "df1_catalunya_q1_predicted_q2_predicted.csv",
#     "df1_red_bull_ring_q1_predicted_q2_predicted.csv",
#     "df1_silverstone_q1_predicted_q2_predicted.csv",
#     "df1_hungaroring_q1_predicted_q2_predicted.csv",
#     "df1_spa_q1_predicted_q2_predicted.csv",
#     "df1_zandvoort_q1_predicted_q2_predicted.csv",
#     "df1_monza_q1_predicted_q2_predicted.csv",
#     "df1_baku_q1_predicted_q2_predicted.csv",
#     "df1_marina_bay_q1_predicted_q2_predicted.csv",
#     "df1_americas_q1_predicted_q2_predicted.csv",
#     "df1_rodriguez_q1_predicted_q2_predicted.csv",
#     "df1_interlagos_q1_predicted_q2_predicted.csv",
#     "df1_losail_q1_predicted_q2_predicted.csv",
#     "df1_yas_marina_q1_predicted_q2_predicted.csv"]

# %% [markdown]
# file_names_trabajo = [
#     "df1_bahrain_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_albert_park_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_suzuka_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_miami_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_imola_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_monaco_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_villeneuve_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_catalunya_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_red_bull_ring_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_silverstone_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_hungaroring_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_spa_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_zandvoort_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_monza_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_baku_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_marina_bay_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_americas_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_rodriguez_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_interlagos_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_losail_q1_predicted_trabajar_posiciones_finales.csv",
#     "df1_yas_marina_q1_predicted_trabajar_posiciones_finales.csv"]

# %%
data2 = pd.read_csv("dfq3.csv")
df2 = data2.copy()
print(df2.circuitref.unique())
# Out:
# ['losail' 'bahrain' 'imola' 'portimao' 'catalunya' 'monaco' 'baku'
#  'red_bull_ring' 'ricard' 'silverstone' 'hungaroring' 'spa' 'zandvoort'
#  'monza' 'sochi' 'istanbul' 'americas' 'rodriguez' 'interlagos' 'jeddah'
#  'yas_marina' 'albert_park' 'miami' 'villeneuve' 'marina_bay' 'suzuka']

# %% [markdown]
# lista_circuitos = ['losail', 'bahrain', 'imola', 'portimao', 'catalunya', 'monaco', 'baku',
#                    'red_bull_ring', 'ricard', 'silverstone', 'hungaroring', 'spa', 'zandvoort',
#                    'monza', 'sochi', 'istanbul', 'americas', 'rodriguez', 'interlagos', 'jeddah',
#                    'yas_marina', 'albert_park', 'miami', 'villeneuve', 'marina_bay', 'suzuka']
#
#
#
# for circuit in lista_circuitos:
#     df3 = df2[df2["circuitref"] == circuit].copy()  # Copia para evitar modificar el original
#     df3 = df3.sort_values(by=['year', 'driverid'], ascending=[True, True])
#     missing_count = 0
#     # Iteramos sobre cada DataFrame en el diccionario
#     for key, df in dfs.items():

# %%
diccionario = {
    "bahrain": "bahrain",
    "albert": "albert_park",
    "losail": "losail",
    "imola": "imola",
    "portimao": "portimao",
    "catalunya": "catalunya",
    "monaco": "monaco",
    "baku": "baku",
    "red": "red_bull_ring",
    "ricard": "ricard",
    "silverstone": "silverstone",
    "hungaroring": "hungaroring",
    "spa": "spa",
    "zandvoort": "zandvoort",
    "monza": "monza",
    "sochi": "sochi",
    "istanbul": "istanbul",
    "americas": "americas",
    "rodriguez": "rodriguez",
    "interlagos": "interlagos",
    "jeddah": "jeddah",
    "yas": "yas_marina",
    "miami": "miami",
    "villeneuve": "villeneuve",
    "marina": "marina_bay",
    "suzuka": "suzuka"}
# Crear una copia del diccionario dfs antes de iterar sobre él
dfs_copy = dfs.copy()
missing_count = 0
# Iterar sobre la copia del diccionario
for key, df in dfs_copy.items():
    variable = key.split("_")[1]
    if variable in diccionario:
        variable1 = diccionario[variable]
        df3 = df2[df2["circuitref"] == variable1]
        dfs[key] = pd.merge(dfs[key], df3[['year', 'driverid', 'q3']], on=['year', 'driverid'], how='left')
        dfs[key]['q3disqualified'] = (dfs[key]['position_q2'] > 10).astype(int)
        dfs[key]["driver_q3vsq2"] = dfs[key]["q3"] - dfs[key]["q2"]
        dfs[key].loc[dfs[key]["q3"] == 0, "driver_q3vsq2"] = 0 
        car_q3vsq2 = dfs[key].groupby(['constructorid', 'year', 'circuitref'])['driver_q3vsq2'].mean().reset_index()
        dfs[key] = pd.merge(dfs[key], car_q3vsq2, on=['constructorid', 'year', 'circuitref'], suffixes=('', '_mean'))
        dfs[key].rename(columns={'driver_q3vsq2_x': 'driver_q3vsq2', 'driver_q3vsq2_mean': 'car_q3vsq2'}, inplace=True)
        dfs[key]['previous_driver_q3vsq2'] = dfs[key].groupby(['circuitref', 'driverid'])['driver_q3vsq2'].shift().fillna(0)
        dfs[key]['previous_car_q3vsq2'] = dfs[key].groupby(['circuitref', 'driverid'])['car_q3vsq2'].shift().fillna(0)
        dfs[key]['position_q3'] = dfs[key].groupby(['circuitref', 'year'])['q3'].rank() 
        dfs[key]['previous_year_position_q3'] = dfs[key].groupby(['circuitref', 'driverid'])['position_q3'].shift().fillna(20)
        column_order = ['qualifyid', 'raceid', 'driverid', 'constructorid', 'position_final',
                        'year', 'round', 'circuitid', 'circuitref', 'car_condition',
                        'driver_condition', 'position_q1', 'previous_year_position_q1',
                        'circuitref_fastlap', 'driver_time_vs_fastlap', 'car_time_vs_fastlap',
                        'previous_driver_time_vs_fastlap', 'previous_car_time_vs_fastlap',
                        'q2disqualified', 'driver_q2vsq1', 'car_q2vsq1',
                        'previous_driver_q2vsq1', 'previous_car_q2vsq1', 'position_q2',
                        'previous_year_position_q2', 'q3disqualified',
                        'driver_q3vsq2', 'car_q3vsq2', 'previous_driver_q3vsq2',
                        'previous_car_q3vsq2', 'position_q3', 'previous_year_position_q3', 'q1', 'q2', 'q3']
        dfs[key] = dfs[key].reindex(columns=column_order)
        dfs[key].to_csv(f'{key}_penultimo.csv', index=False)
        dfs[key] = dfs[key][dfs[key]["q3disqualified"] == 0]
        
        
        
        max_q3 = dfs[key]['q3'].max()
        dfs[key]['q3'].replace(0, max_q3, inplace=True)       
        
        
        
        
        drop_list = ["position_final", "circuitref", "driver_time_vs_fastlap",
                    "car_time_vs_fastlap", "raceid", "car_condition", 'position_q3',
                    "driver_condition", 'driver_q2vsq1', 'car_q2vsq1', 'q1', 'q2', 'q3',
                    "car_q3vsq2", "driver_q3vsq2"]
        X = dfs[key].drop(drop_list, axis=1)
        y = dfs[key]["q3"]
        X_2024 = X[X['year'] == 2024]
        X_train, X_test, y_train, y_test = train_test_split(X[X['year'] != 2024], y[X['year'] != 2024],
                                                            test_size=0.02, random_state=0)

        xgbr = xgb.XGBRFRegressor()
        xgbr.fit(X_train, y_train)
        predictions_xgb_2024 = xgbr.predict(X_2024)
        series_pred_2024 = pd.Series(predictions_xgb_2024, name='q3')
        duplicates = series_pred_2024[series_pred_2024.duplicated(keep=False)]
        duplicate_count = 0
        for index in duplicates.index:
            duplicate_count += 1
            value_to_add = duplicate_count - 1
            series_pred_2024[index] += value_to_add 
        dfs[f"{key}_2024"] = pd.concat([X_2024.reset_index(drop=True), series_pred_2024], axis=1)
        
        
        
        dfs[f"{key}_2024"]['position_q3'] = dfs[f"{key}_2024"]['q3'].rank(method='min')
        
        
        
        dfs[f"{key}_2024"].to_csv(f'{key}_q3_predicted_2024.csv', index=False)
        if dfs[key].empty:
            missing_count += 1
print(f"Total de df_track_name faltantes: {missing_count}")
# Out:
# Total de df_track_name faltantes: 0

# %% [markdown]
# series_pred_2024 = pd.Series(predictions_xgb_2024, name='q3')
# como puedo hacer para que si hay algun valor repetido se le sume 1 al segundo valor repetido hasta que ya no haya valores repetidos

# %% [markdown]
# <h4 style="color: #F70206;">Columnas categoricas y numericas</h4>

# %% [markdown]
# <h1 style="color: #F70206; text-shadow: 2px 2px 4px #000000; border: 1px solid #000000; font-size: 36px;">05 | Improving the Model</h1>
